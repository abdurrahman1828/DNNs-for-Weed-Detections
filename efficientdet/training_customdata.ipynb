# %%
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
python train.py --model-type d0  --use-pretrain True --dataset-type coco --num-classes 3 --class-names dataset/weed.names --dataset D:/Abdur/centernet_data/train --coco-train-set train2017 --coco-val-set val2017 --epochs 200 --batch-size 16 #--augment ssd_random_crop
